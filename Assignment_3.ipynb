# %%
# !pip install torch torchvision numpy tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
import torch
from torch import nn, optim
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets
import numpy as np

class CustomFashionMNIST(Dataset):
    def __init__(self, root='./data', train=True, transform=None):
        self.dataset = datasets.FashionMNIST(root=root, train=train, download=True)
        self.data = self.dataset.data.float().unsqueeze(1) / 255.0
        self.labels = self.dataset.targets
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image, label = self.data[idx], self.labels[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

class FashionModel(nn.Module):
    def __init__(self):
        super(FashionModel, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1), nn.BatchNorm2d(32), nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(),
            nn.Flatten(),
            nn.Linear(128 * 7 * 7, 256), nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        return self.model(x)

class ModelTrainer:
    def __init__(self, model, device, learning_rate=0.001):
        self.model = model.to(device)
        self.device = device
        self.criterion = nn.CrossEntropyLoss()
        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)
        self.best_accuracy = 0.0

    def train_epoch(self, data_loader):
        self.model.train()
        running_loss = 0.0
        for images, labels in data_loader:
            images, labels = images.to(self.device), labels.to(self.device)
            self.optimizer.zero_grad()
            outputs = self.model(images)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()
            running_loss += loss.item()
        return running_loss / len(data_loader)

    def evaluate(self, data_loader):
        self.model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for images, labels in data_loader:
                images, labels = images.to(self.device), labels.to(self.device)
                outputs = self.model(images)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        return 100 * correct / total

    def save_best_model(self, epoch, accuracy, filename='CNN_Model.pt'):
        if accuracy > self.best_accuracy:
            self.best_accuracy = accuracy
            torch.save({
                'epoch': epoch,
                'model_state_dict': self.model.state_dict(),
                'accuracy': accuracy
            }, filename)
            print(f"New best model saved with accuracy {accuracy:.2f}% at epoch {epoch}.")

    def load_model(self, filename='CNN_Model.pt'):
        checkpoint = torch.load(filename, map_location=self.device)
        self.model.load_state_dict(checkpoint['model_state_dict'])
        self.best_accuracy = checkpoint['accuracy']
        print(f"Model loaded with accuracy {self.best_accuracy:.2f}%.")

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    train_dataset = CustomFashionMNIST(train=True)
    test_dataset = CustomFashionMNIST(train=False)
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

    model = FashionModel()
    trainer = ModelTrainer(model, device)

    num_epochs = 108
    print("Starting training")
    for epoch in range(1, num_epochs + 1):
        train_loss = trainer.train_epoch(train_loader)
        print(f"Epoch {epoch} | Training Loss: {train_loss:.4f}")

        test_accuracy = trainer.evaluate(test_loader)
        print(f"Epoch {epoch} | Test Accuracy: {test_accuracy:.2f}%")

        trainer.save_best_model(epoch, test_accuracy)

    print(f"\nTraining complete. Best accuracy: {trainer.best_accuracy:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Starting training
# Epoch 1 | Training Loss: 0.4207
# Epoch 1 | Test Accuracy: 86.70%
# New best model saved with accuracy 86.70% at epoch 1.
# Epoch 2 | Training Loss: 0.2905
# Epoch 2 | Test Accuracy: 89.24%
# New best model saved with accuracy 89.24% at epoch 2.
# Epoch 3 | Training Loss: 0.2478
# Epoch 3 | Test Accuracy: 91.40%
# New best model saved with accuracy 91.40% at epoch 3.
# Epoch 4 | Training Loss: 0.2139
# Epoch 4 | Test Accuracy: 91.20%
# Epoch 5 | Training Loss: 0.1904
# Epoch 5 | Test Accuracy: 92.19%
# New best model saved with accuracy 92.19% at epoch 5.
# Epoch 6 | Training Loss: 0.1695
# Epoch 6 | Test Accuracy: 92.23%
# New best model saved with accuracy 92.23% at epoch 6.
# Epoch 7 | Training Loss: 0.1466
# Epoch 7 | Test Accuracy: 92.16%
# Epoch 8 | Training Loss: 0.1307
# Epoch 8 | Test Accuracy: 92.33%
# New best model saved with accuracy 92.33% at epoch 8.
# Epoch 9 | Training Loss: 0.1154
# Epoch 9 | Test Accuracy: 92.72%
# New best model saved with accuracy 92.72% at epoch 9.
# Epoch 10 | Training Loss: 0.1028
# Epoch 10 | Test Accuracy: 92.79%
# New best model saved with accuracy 92.79% at epoch 10.
# Epoch 11 | Training Loss: 0.0887
# Epoch 11 | Test Accuracy: 92.54%
# Epoch 12 | Training Loss: 0.0805
# Epoch 12 | Test Accuracy: 92.64%
# Epoch 13 | Training Loss: 0.0711
# Epoch 13 | Test Accuracy: 92.86%
# New best model saved with accuracy 92.86% at epoch 13.
# Epoch 14 | Training Loss: 0.0663
# Epoch 14 | Test Accuracy: 92.30%
# Epoch 15 | Training Loss: 0.0614
# Epoch 15 | Test Accuracy: 92.12%
# Epoch 16 | Training Loss: 0.0547
# Epoch 16 | Test Accuracy: 92.71%
# Epoch 17 | Training Loss: 0.0508
# Epoch 17 | Test Accuracy: 92.57%
# Epoch 18 | Training Loss: 0.0480
# Epoch 18 | Test Accuracy: 92.64%
# Epoch 19 | Training Loss: 0.0469
# Epoch 19 | Test Accuracy: 92.73%
# Epoch 20 | Training Loss: 0.0385
# Epoch 20 | Test Accuracy: 92.50%
# Epoch 21 | Training Loss: 0.0394
# Epoch 21 | Test Accuracy: 92.85%
# Epoch 22 | Training Loss: 0.0369
# Epoch 22 | Test Accuracy: 92.53%
# Epoch 23 | Training Loss: 0.0371
# Epoch 23 | Test Accuracy: 92.56%
# Epoch 24 | Training Loss: 0.0336
# Epoch 24 | Test Accuracy: 92.22%
# Epoch 25 | Training Loss: 0.0329
# Epoch 25 | Test Accuracy: 92.96%
# New best model saved with accuracy 92.96% at epoch 25.
# Epoch 26 | Training Loss: 0.0349
# Epoch 26 | Test Accuracy: 92.70%
# Epoch 27 | Training Loss: 0.0293
# Epoch 27 | Test Accuracy: 92.58%
# Epoch 28 | Training Loss: 0.0322
# Epoch 28 | Test Accuracy: 92.36%
# Epoch 29 | Training Loss: 0.0268
# Epoch 29 | Test Accuracy: 92.51%
# Epoch 30 | Training Loss: 0.0253
# Epoch 30 | Test Accuracy: 92.62%
# Epoch 31 | Training Loss: 0.0268
# Epoch 31 | Test Accuracy: 92.59%
# Epoch 32 | Training Loss: 0.0271
# Epoch 32 | Test Accuracy: 92.71%
# Epoch 33 | Training Loss: 0.0253
# Epoch 33 | Test Accuracy: 92.89%
# Epoch 34 | Training Loss: 0.0228
# Epoch 34 | Test Accuracy: 92.23%
# Epoch 35 | Training Loss: 0.0243
# Epoch 35 | Test Accuracy: 92.25%
# Epoch 36 | Training Loss: 0.0222
# Epoch 36 | Test Accuracy: 92.65%
# Epoch 37 | Training Loss: 0.0220
# Epoch 37 | Test Accuracy: 92.57%
# Epoch 38 | Training Loss: 0.0225
# Epoch 38 | Test Accuracy: 92.20%
# Epoch 39 | Training Loss: 0.0228
# Epoch 39 | Test Accuracy: 92.46%
# Epoch 40 | Training Loss: 0.0205
# Epoch 40 | Test Accuracy: 92.50%
# Epoch 41 | Training Loss: 0.0218
# Epoch 41 | Test Accuracy: 92.80%
# Epoch 42 | Training Loss: 0.0228
# Epoch 42 | Test Accuracy: 92.58%
# Epoch 43 | Training Loss: 0.0180
# Epoch 43 | Test Accuracy: 92.58%
# Epoch 44 | Training Loss: 0.0195
# Epoch 44 | Test Accuracy: 92.32%
# Epoch 45 | Training Loss: 0.0207
# Epoch 45 | Test Accuracy: 92.51%
# Epoch 46 | Training Loss: 0.0194
# Epoch 46 | Test Accuracy: 92.81%
# Epoch 47 | Training Loss: 0.0189
# Epoch 47 | Test Accuracy: 92.38%
# Epoch 48 | Training Loss: 0.0164
# Epoch 48 | Test Accuracy: 92.43%
# Epoch 49 | Training Loss: 0.0182
# Epoch 49 | Test Accuracy: 92.55%
# Epoch 50 | Training Loss: 0.0181
# Epoch 50 | Test Accuracy: 92.73%
# Epoch 51 | Training Loss: 0.0176
# Epoch 51 | Test Accuracy: 92.43%
# Epoch 52 | Training Loss: 0.0178
# Epoch 52 | Test Accuracy: 92.37%
# Epoch 53 | Training Loss: 0.0186
# Epoch 53 | Test Accuracy: 92.44%
# Epoch 54 | Training Loss: 0.0157
# Epoch 54 | Test Accuracy: 92.34%
# Epoch 55 | Training Loss: 0.0159
# Epoch 55 | Test Accuracy: 92.31%
# Epoch 56 | Training Loss: 0.0173
# Epoch 56 | Test Accuracy: 92.40%
# Epoch 57 | Training Loss: 0.0166
# Epoch 57 | Test Accuracy: 92.53%
# Epoch 58 | Training Loss: 0.0125
# Epoch 58 | Test Accuracy: 92.50%
# Epoch 59 | Training Loss: 0.0160
# Epoch 59 | Test Accuracy: 92.21%
# Epoch 60 | Training Loss: 0.0149
# Epoch 60 | Test Accuracy: 92.49%
# Epoch 61 | Training Loss: 0.0170
# Epoch 61 | Test Accuracy: 92.65%
# Epoch 62 | Training Loss: 0.0155
# Epoch 62 | Test Accuracy: 92.62%
# Epoch 63 | Training Loss: 0.0171
# Epoch 63 | Test Accuracy: 92.44%
# Epoch 64 | Training Loss: 0.0144
# Epoch 64 | Test Accuracy: 92.64%
# Epoch 65 | Training Loss: 0.0137
# Epoch 65 | Test Accuracy: 92.75%
# Epoch 66 | Training Loss: 0.0160
# Epoch 66 | Test Accuracy: 92.28%
# Epoch 67 | Training Loss: 0.0132
# Epoch 67 | Test Accuracy: 91.93%
# Epoch 68 | Training Loss: 0.0154
# Epoch 68 | Test Accuracy: 92.39%
# Epoch 69 | Training Loss: 0.0115
# Epoch 69 | Test Accuracy: 92.75%
# Epoch 70 | Training Loss: 0.0151
# Epoch 70 | Test Accuracy: 92.38%
# Epoch 71 | Training Loss: 0.0127
# Epoch 71 | Test Accuracy: 92.76%
# Epoch 72 | Training Loss: 0.0139
# Epoch 72 | Test Accuracy: 92.28%
# Epoch 73 | Training Loss: 0.0135
# Epoch 73 | Test Accuracy: 92.34%
# Epoch 74 | Training Loss: 0.0125
# Epoch 74 | Test Accuracy: 92.38%
# Epoch 75 | Training Loss: 0.0115
# Epoch 75 | Test Accuracy: 92.23%
# Epoch 76 | Training Loss: 0.0148
# Epoch 76 | Test Accuracy: 92.48%
# Epoch 77 | Training Loss: 0.0116
# Epoch 77 | Test Accuracy: 92.09%
# Epoch 78 | Training Loss: 0.0141
# Epoch 78 | Test Accuracy: 92.70%
# Epoch 79 | Training Loss: 0.0119
# Epoch 79 | Test Accuracy: 92.33%
# Epoch 80 | Training Loss: 0.0125
# Epoch 80 | Test Accuracy: 92.58%
# Epoch 81 | Training Loss: 0.0115
# Epoch 81 | Test Accuracy: 92.53%
# Epoch 82 | Training Loss: 0.0137
# Epoch 82 | Test Accuracy: 92.58%
# Epoch 83 | Training Loss: 0.0090
# Epoch 83 | Test Accuracy: 91.99%
# Epoch 84 | Training Loss: 0.0124
# Epoch 84 | Test Accuracy: 92.47%
# Epoch 85 | Training Loss: 0.0135
# Epoch 85 | Test Accuracy: 92.46%
# Epoch 86 | Training Loss: 0.0103
# Epoch 86 | Test Accuracy: 92.74%
# Epoch 87 | Training Loss: 0.0122
# Epoch 87 | Test Accuracy: 92.68%
# Epoch 88 | Training Loss: 0.0138
# Epoch 88 | Test Accuracy: 92.51%
# Epoch 89 | Training Loss: 0.0113
# Epoch 89 | Test Accuracy: 92.41%
# Epoch 90 | Training Loss: 0.0098
# Epoch 90 | Test Accuracy: 92.84%
# Epoch 91 | Training Loss: 0.0123
# Epoch 91 | Test Accuracy: 92.44%
# Epoch 92 | Training Loss: 0.0110
# Epoch 92 | Test Accuracy: 92.59%
# Epoch 93 | Training Loss: 0.0091
# Epoch 93 | Test Accuracy: 92.72%
# Epoch 94 | Training Loss: 0.0106
# Epoch 94 | Test Accuracy: 92.54%
# Epoch 95 | Training Loss: 0.0114
# Epoch 95 | Test Accuracy: 92.65%
# Epoch 96 | Training Loss: 0.0113
# Epoch 96 | Test Accuracy: 92.15%
# Epoch 97 | Training Loss: 0.0102
# Epoch 97 | Test Accuracy: 92.61%
# Epoch 98 | Training Loss: 0.0103
# Epoch 98 | Test Accuracy: 92.59%
# Epoch 99 | Training Loss: 0.0115
# Epoch 99 | Test Accuracy: 92.72%
# Epoch 100 | Training Loss: 0.0097
# Epoch 100 | Test Accuracy: 92.62%
# Epoch 101 | Training Loss: 0.0126
# Epoch 101 | Test Accuracy: 92.72%
# Epoch 102 | Training Loss: 0.0113
# Epoch 102 | Test Accuracy: 92.21%
# Epoch 103 | Training Loss: 0.0084
# Epoch 103 | Test Accuracy: 92.45%
# Epoch 104 | Training Loss: 0.0114
# Epoch 104 | Test Accuracy: 92.84%
# Epoch 105 | Training Loss: 0.0094
# Epoch 105 | Test Accuracy: 92.63%
# Epoch 106 | Training Loss: 0.0107
# Epoch 106 | Test Accuracy: 92.42%
# Epoch 107 | Training Loss: 0.0119
# Epoch 107 | Test Accuracy: 92.58%
# Epoch 108 | Training Loss: 0.0106
# Epoch 108 | Test Accuracy: 92.61%
#
# Training complete. Best accuracy: 92.96%
